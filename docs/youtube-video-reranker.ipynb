# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd


fetched_videos= [
  {
    "video_id": "1",
    "title": "Best AI Coding Tools for Developers in 2025",
    "description": "Explore the top AI coding tools of 2025 that are changing software development. From **GitHub Copilot** and **Claude** to **Cursor IDE** and **Windsurf**, these AI tools help you write code faster and more efficiently. Learn about conversational assistants, AI IDEs, app builders, and design-to-code conversion tools.",
    "domain": "AI Coding Tools"
  },
  {
    "video_id": "2", 
    "title": "Best AI Tools for Programming in 2025",
    "description": "AI coding assistants make programming easier and faster by suggesting code in real-time. These tools help developers focus on what matters most - thinking! Covers **GitHub Copilot**, **Amazon Q Developer**, **Codeium**, **Claude**, **ChatGPT**, and more productivity tools.",
    "domain": "AI Coding Tools"
  },
  {
    "video_id": "3",
    "title": "Best AI Tools for Programmers in 2025",
    "description": "Level up your coding with top AI tools! From writing code to debugging, these AI tools are perfect for developers and tech enthusiasts. Features **DeepSeek AI**, **Claude AI**, **Tabnine**, and **Cursor AI** for enhanced coding productivity.",
    "domain": "AI Coding Tools"
  },
  {
    "video_id": "4",
    "title": "Best AI Coding Tool for Developers | Top Free AI Tools for Programmers",
    "description": "Want to code faster and smarter with AI? Learn about the best **free AI coding assistants** and step-by-step guides to using AI for coding. Generate, debug, and optimize code with AI-powered tools that boost productivity for beginners and experienced programmers.",
    "domain": "AI Coding Tools"
  },
  {
    "video_id": "5",
    "title": "7 Best AI Tools You NEED to Try in 2025 (Free & Powerful!)",
    "description": "Discover 7 must-try AI tools to boost productivity and automate tasks! Features **Zapier** for automation, **Google AI Studio**, **ChatGPT**, **Udio** for music generation, **ElevenLabs** for voice generation, **Perplexity AI** for search, and **Descript** for video editing.",
    "domain": "General AI Tools"
  },
  {
    "video_id": "6",
    "title": "We Tested Google's New AI Coding Tool Opal (Honest Review)",
    "description": "Deep dive into **Google Opal**, the experimental no-code tool for building AI-powered mini-apps using natural language and visual workflows. Honest review of building and customizing apps without writing code - is it worth it?",
    "domain": "AI Coding Tools"
  },
  {
    "video_id": "7",
    "title": "Claude Code Sub-Agents: BEST AI Coder! SUPERCHARGE Claude Code",
    "description": "**Claude Code** gets a massive upgrade with **Subagents** - specialized multi-agents in your terminal! The **Delegator** acts as an AI project manager that researches, writes tasks, and launches background agents. It's like having a full dev team on autopilot!",
    "domain": "AI Coding Tools"
  },
  {
    "video_id": "8",
    "title": "Install DeepSeek in VS Code in 30 Seconds",
    "description": "Quick tutorial on setting up **DeepSeek AI** in **VS Code** for enhanced coding assistance. Simple 30-second installation process for AI-powered code completion and suggestions.",
    "domain": "AI Coding Tools"
  },
  {
    "video_id": "9",
    "title": "Top Free AI Coding Tool 2025 | Windsurf & Cursor Free Alternative",
    "description": "Best **free AI coding editor** alternatives to **Windsurf** and **Cursor**. Discover unlimited free coding tools including **Codeium AI**, **Tabnine**, and other AI-powered development platforms for enhanced productivity.",
    "domain": "AI Coding Tools"
  },
  {
    "video_id": "10",
    "title": "Advanced AI Code Generator",
    "description": "AI code generators can write code based on your input, helping you save time and avoid errors. Learn how to use AI code generation tools to create web apps in minutes across different programming languages and frameworks.",
    "domain": "AI Coding Tools"
  },
  {
    "video_id": "11",
    "title": "AI Tools You NEED in 2025",
    "description": "Essential AI tools for 2025 that will boost your productivity and workflow. Quick overview of must-have AI applications for various tasks and industries.",
    "domain": "General AI Tools"
  },
  {
    "video_id": "12",
    "title": "Gemini CLI vs Claude Code vs Codex Compared! Should You Use an AI CLI?",
    "description": "Comprehensive comparison of coding CLIs including **Gemini CLI**, **Claude Code**, and **OpenAI Codex CLI**. Test how they perform for coding tasks inside **VS Code**, **Cursor**, and with **MCP** to see which you should use.",
    "domain": "AI Coding Tools"
  },
  {
    "video_id": "13",
    "title": "Replit: Best AI Coding Tool for Beginners?",
    "description": "**Replit** might be the best AI coding tool for beginners in 2025. Go from zero to a published app with custom domain in one afternoon! Features AI-powered code generation, one-click deployment, built-in authentication, and visual editor.",
    "domain": "AI Coding Tools"
  },
  {
    "video_id": "14",
    "title": "Top 3 AI Coding Assistant for Programmers 2025",
    "description": "Top AI coding assistants that supercharge your coding workflow: **CodeGeex**, **GitHub Copilot**, and **Codeium**. Learn about code completion, error detection, natural language programming, and code generation features.",
    "domain": "AI Coding Tools"
  },
  {
    "video_id": "15",
    "title": "9 AI Tools That Will Separate Winners from Losers in 2025",
    "description": "Discover the 9 AI tools for building apps, automating workflows, and creating pro-level content without coding. Learn how to become an **AI generalist** using tools like **Lovable.ai**, **Relevance AI**, and **ChatGPT 4o** for maximum productivity.",
    "domain": "General AI Tools"
  },
  {
    "video_id": "16",
    "title": "GitHub Copilot Agent vs Cursor AI — Best AI Coding Tool in 2025?",
    "description": "Compare **GitHub Copilot Agent** and **Cursor AI** for speed, performance, code accuracy, debugging, and autocomplete features. Which AI coding assistant is best for beginners vs pros in 2025?",
    "domain": "AI Coding Tools"
  },
  {
    "video_id": "17",
    "title": "9 AI Tools You MUST Be Using in 2025",
    "description": "Essential AI tools for 2025 covering content generation, cold outreach, AI image/video generation, music generation, and content research. Features **HeyGen**, **ElevenLabs**, **Suno AI**, **NotebookLM**, **Claude**, **Omi**, **Flux AI**, and **Perplexity**.",
    "domain": "General AI Tools"
  },
  {
    "video_id": "18",
    "title": "Best PAID AI Tools Free Alternatives 2025",
    "description": "Discover free alternatives to expensive paid AI tools in 2025. Save money while maintaining productivity with these powerful free AI solutions for various tasks.",
    "domain": "General AI Tools"
  },
  {
    "video_id": "19",
    "title": "BEST AI TOOLS TO USE IN 2025!",
    "description": "Top AI tools for video editing, content creation, business, research, and graphic design. Essential tools including **Notebook LM**, **Sora**, **Google AI Studio** for maximum productivity in 2025.",
    "domain": "General AI Tools"
  },
  {
    "video_id": "20",
    "title": "Best 5 Free AI Tools in 2025 | Must-Try AI Software for Productivity & Creativity",
    "description": "Discover the 5 best **free AI tools** in 2025 for content creators, entrepreneurs, students, and business owners. AI-powered tools for writing, design, video editing, coding, and automation to save time and boost efficiency.",
    "domain": "General AI Tools"
  },
  {
    "video_id": "21",
    "title": "What is Agentic AI and How Does it Work?",
    "description": "Simple explanation of **Agentic AI** systems compared to workflows using LLMs. Learn the difference between RAG-based AI systems, tool-augmented AI systems, and true agentic AI applications with practical examples.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "22",
    "title": "What is Agentic AI? An Easy Explanation For Everyone",
    "description": "Dive into **Agentic AI** where AI systems act autonomously to achieve goals without human guidance. From personal assistants to autonomous vehicles, learn about its growing impact and ethical considerations.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "23",
    "title": "AI Agent vs. Agentic AI: What's the real difference?",
    "description": "Clear up the confusion between **AI agents** and **Agentic AI**. Understand the key differences and how these concepts relate to modern AI development and automation.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "24",
    "title": "Generative vs Agentic AI: Shaping the Future of AI Collaboration",
    "description": "Learn the difference between **generative AI** and **agentic AI**. Generative AI powers content creation, while agentic AI uses LLMs and chain of thought reasoning for proactive tasks like personal shopping and planning.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "25",
    "title": "Generative AI vs AI Agents vs Agentic AI",
    "description": "Simple, intuitive explanation of the differences between **generative AI**, **AI agents**, and **agentic AI systems**. Understand how these technologies work and their practical applications with clear examples.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "26",
    "title": "What's The Difference Between AI Agents And Agentic AI?",
    "description": "**AI agents** are specific applications solving multi-step problems independently, while **agentic AI** is the research field making these agents possible. Think of AI agents as medicines and agentic AI as pharmaceutical science.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "27",
    "title": "Amazon Bedrock AgentCore: Deploy & Operate AI Agents in Minutes",
    "description": "**Amazon Bedrock AgentCore** - comprehensive, modular, fully-managed services to deploy and operate production-ready **AI agents** at scale. Features secure serverless runtimes, memory management, and enterprise-grade monitoring.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "28",
    "title": "Agentic AI Explained So Anyone Can Get It!",
    "description": "**Agentic AI** goes beyond prompts to act, learn, and evolve like autonomous systems. Learn the architecture from perception to action, and how to build AI agents using **GPT-4**, **LangChain**, and **OpenAI's Agent SDK**.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "29",
    "title": "Agentic AI Explained",
    "description": "Introduction to **Agentic AI** with code examples. Simple explanation of how agentic AI systems work and their practical applications in modern AI development.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "30",
    "title": "Generative AI Vs Agentic AI Vs AI Agents",
    "description": "Detailed discussion on differences between **generative AI**, **agentic AI**, and **AI agents**. Agentic AI acts autonomously, adapts in real time, and solves multi-step problems based on context and objectives.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "31",
    "title": "AI Agents, Clearly Explained",
    "description": "Understanding **AI Agents** evolution from basic LLMs like **ChatGPT** to AI Workflows and true AI Agents. Learn key differences, **RAG**, **ReAct**, and how these technologies impact daily life through practical examples.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "32",
    "title": "Agentic AI: Workflows vs. Agents",
    "description": "What is **agentic AI** and how to apply it in applications? Learn about agentic workflows, how agents differ from workflows, and when to use agentic workflows with practical code examples.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "33",
    "title": "Best Agentic AI Framework",
    "description": "Review of prominent **agentic AI frameworks**: **Agno**, **LangGraph**, **CrewAI**, **Google ADK**, **OpenAI ADK**, and no-code options like **N8N** and **Make.com**. Learn which framework is best for your situation.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "34",
    "title": "Risks of Agentic AI: What You Need to Know About Autonomous AI",
    "description": "**Agentic AI** brings risks like misinformation, security gaps, and decision-making errors. Learn about AI governance strategies and responsible deployment of autonomous AI systems.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "35",
    "title": "Agentic AI vs AI Agents – What's the Difference?",
    "description": "**Agentic AI** doesn't just respond to prompts - it thinks, plans, and executes tasks autonomously. Learn its impact across software development, healthcare, logistics, and HR, plus common myths about job replacement.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "36",
    "title": "Master Agentic AI in 2025 with This Proven Roadmap!",
    "description": "Complete roadmap for mastering **Agentic AI** in 2025. Learn about **Crew AI**, **Langchain**, **Autogen**, and essential skills for agentic AI projects and careers.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "37",
    "title": "What is Agentic AI? Important For GEN AI In 2025",
    "description": "**Agentic AI** or AI agents are software systems performing tasks autonomously with minimal human intervention. They're goal-oriented and represent the third wave of AI - a fundamental shift in AI interaction.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "38",
    "title": "What is Agentic RAG?",
    "description": "Discover **Agentic RAG** - a powerful pipeline enhancing responses from large language models by incorporating relevant data from vector databases. Creates more responsive, accurate, and adaptable AI systems.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "39",
    "title": "Agentic AI Tutorial for Beginners | Langgraph Tutorial",
    "description": "Learn **Agentic AI** using **Langgraph** framework. Comprehensive tutorial covering agentic AI basics, simple graphs, conditions, chatbots with tools, memory, tracing with **Langsmith**, and human-in-the-loop patterns.",
    "domain": "Agentic AI"
  },
  {
    "video_id": "40",
    "title": "What is Agentic AI and why is it important?",
    "description": "Quick explanation of **Agentic AI** and its importance in the current AI landscape. Understanding why agentic AI represents a significant advancement in artificial intelligence capabilities.",
    "domain": "Agentic AI"
  },
     {
    "video_id": "81",
    "title": "Computer Vision Explained in 5 Minutes | AI Explained",
    "description": "Quick explanation of **Computer Vision** and its core concepts. Understanding how computers interpret and process visual information from the world, including techniques like image recognition, object detection, and real-world applications in AI.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "82", 
    "title": "20 Best Computer Vision Projects for 2025!",
    "description": "Comprehensive showcase of **Computer Vision Projects** including robotic arms, face tracking robots, sign language translators, and automated systems. Practical examples demonstrating real-world applications of computer vision technology.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "83",
    "title": "MSF MES & Computer Vision Quality Control – Real Installation Example", 
    "description": "Real-world implementation of **Computer Vision in Manufacturing** showing how AI-based visual inspection systems integrate with Manufacturing Execution Systems for automated quality control and defect detection.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "84",
    "title": "Computer Vision Syndrome",
    "description": "Medical perspective on **Computer Vision Syndrome** - the eye strain and discomfort caused by prolonged computer use. Understanding the health implications of extended screen time and digital eye strain.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "85",
    "title": "Computer Vision: Crash Course Computer Science #35",
    "description": "Educational overview of **Computer Vision fundamentals** covering how computers process images, facial recognition, biometrics, autonomous vehicles, and the mathematical foundations including convolutional neural networks.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "86",
    "title": "How Computer Vision Works",
    "description": "Technical explanation of **Computer Vision mechanisms** focusing on Convolutional Neural Networks, machine learning models, and practical implementation through Google Cloud Vision and Video Intelligence APIs.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "87",
    "title": "Computer Vision in 100 Seconds",
    "description": "Quick overview of **Computer Vision technology** covering CNNs, deep learning, object detection, image segmentation, and applications in generative AI, self-driving cars, and medical imaging.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "88",
    "title": "What Is Computer Vision & Why Does It Matter?",
    "description": "Introduction to **Computer Vision importance** explaining how computer vision works, different types and tasks, industry applications, and practical examples of object classification and visual data processing.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "89",
    "title": "Azure Computer Vision desde cero | Tutorial + Caso Práctico",
    "description": "Comprehensive tutorial on **Azure Computer Vision** covering image analysis, object detection, and practical implementation. Spanish-language tutorial with real-world case studies and step-by-step guidance.",
    "domain": "Computer Vision" 
  },
  {
    "video_id": "90",
    "title": "What Is Computer Vision? #arduino #mechatronics #computervision",
    "description": "Brief introduction to **Computer Vision basics** in the context of Arduino and mechatronics applications. Quick explanation of how computer vision integrates with hardware systems and robotics.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "91",
    "title": "Computer Vision Explained", 
    "description": "Detailed explanation of **Computer Vision fundamentals** covering image processing, neural networks, CNNs, Transformers, GANs, and real-world applications across industries like autonomous driving and medical imaging.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "92",
    "title": "Automated Shirt Size Measurement - Computer Vision Web Development",
    "description": "Practical application of **Computer Vision in E-commerce** demonstrating automated clothing size measurement for online retail. Example of commercial computer vision web application development.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "93",
    "title": "Why Computer Vision Is a Hard Problem for AI",
    "description": "Academic perspective on **Computer Vision challenges** discussing the complexity of machine vision, self-supervised learning, test-time training, and the future of computer vision research.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "94",
    "title": "What is Computer Vision? | Introduction",
    "description": "Academic introduction to **Computer Vision principles** from Columbia University covering the physical and mathematical foundations of machine vision and computational imaging.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "95",
    "title": "How Computer Vision Applications Work",
    "description": "Technical explanation of **Computer Vision applications** covering neural networks, CNNs, model training, and practical uses in healthcare, autonomous vehicles, and security systems.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "96",
    "title": "What is Computer Vision? | How does it work? | Watch to Know!",
    "description": "Educational overview of **Computer Vision technology** explaining algorithms, deep learning models, CNNs, and practical applications using OpenCV for real-time image and video processing.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "97",
    "title": "How Computer Vision Works",
    "description": "Practical explanation of **Computer Vision mechanics** featuring real-world applications in farming robots and Tesla's self-driving cars, demonstrating how computers learn to classify and recognize images.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "98", 
    "title": "Basic Computer Vision with ML (ML Zero to Hero - Part 2)",
    "description": "Tutorial on **Computer Vision with Machine Learning** using TensorFlow, teaching computers to recognize objects and understand visual patterns through practical coding examples.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "99",
    "title": "Image Processing VS Computer Vision: What's The Difference?",
    "description": "Educational comparison between **Image Processing and Computer Vision** explaining the fundamental differences: image processing modifies images while computer vision extracts information from images.",
    "domain": "Computer Vision"
  },
  {
    "video_id": "100",
    "title": "Computer Vision Class 10",
    "description": "Educational content on **Computer Vision for students** covering AI applications, image recognition, object detection, facial recognition, and real-world applications in various industries.",
    "domain": "Computer Vision"
  }
]

# %%
user_histories = {
    "user_nlp": [
        {"video_id": "h1", "title": "BERT Embeddings for Text Similarity: Hands-on Tutorial", "description": "Learn how to leverage **BERT** to generate powerful **sentence embeddings** and efficiently find similar texts in your datasets. This practical guide covers everything from setup to application."},
        {"video_id": "h2", "title": "Introduction to Named Entity Recognition (NER) with spaCy & Hugging Face", "description": "Master the art of extracting crucial information like **names, places, and dates** from unstructured text using industry-standard libraries like **spaCy** and the latest **transformer models** from Hugging Face."},
        {"video_id": "h3", "title": "Boosting Information Retrieval with Large Language Models (LLMs)", "description": "Discover how cutting-edge **Large Language Models** are revolutionizing **document retrieval and ranking**. Understand the techniques to integrate LLMs for more intelligent and context-aware search systems."}
    ],
    "user_cv": [
        {"video_id": "h4", "title": "Build a Real-Time Face Recognition System with OpenCV & Deep Learning", "description": "Create a complete **end-to-end face recognition pipeline** from scratch. This tutorial dives into practical implementation using **OpenCV** and advanced **deep learning techniques** for robust face identification."},
        {"video_id": "h5", "title": "Transfer Learning with ResNet: Accelerating Image Classification", "description": "Unlock the power of **transfer learning**! Learn how to effectively utilize **pre-trained ResNet models** to achieve state-of-the-art performance on your custom **image classification tasks** with minimal data."},
        {"video_id": "h6", "title": "Deep Learning in Medical Imaging: CNNs for Radiology & Healthcare", "description": "Explore the impactful applications of **Convolutional Neural Networks (CNNs)** in the medical field. This video covers how deep learning is transforming **radiology, disease diagnosis**, and various other healthcare domains."}
    ],
    "user_tools": [
        {"video_id": "h7", "title": "How GitHub Copilot Works: An Inside Look at AI Code Generation", "description": "Demystify **GitHub Copilot**! Go behind the scenes to understand the **inner workings** of this powerful AI coding assistant and the **Codex-based language models** that power its impressive code generation capabilities."},
        {"video_id": "h8", "title": "Advanced LLM API Wrappers: Building Complex Chains & Agents with LangChain", "description": "Elevate your **LangChain** skills! This video focuses on constructing sophisticated **LLM API wrappers**, implementing intricate **chains with memory**, and developing intelligent **agents** for complex AI applications."},
        {"video_id": "h9", "title": "Debugging Prompt Failures in LLM Applications: A Troubleshooting Guide", "description": "Frustrated with inconsistent LLM outputs? This essential guide provides practical **tips and strategies** for **understanding, identifying, and fixing common prompt-related errors** in your Large Language Model applications."}
    ]
}

# %%
! pip install sentence-transformers
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...

# %%
from sentence_transformers import CrossEncoder
import pandas as pd

def rerank_videos_for_user(user_id, user_histories, fetched_videos):
    # Step 1: Create pseudo-query from user's watch history
    user_query = " ".join([
        f"{video['title']}. {video['description']}"
        for video in user_histories[user_id]
    ])

    # Step 2: Create (query, document) pairs
    reranker_input = [
        (
            user_query,
            f"{video['title']}. {video['description']}"
        )
        for video in fetched_videos
    ]

    # Step 3: Load reranker model and predict scores
    model = CrossEncoder("BAAI/bge-reranker-base")
    scores = model.predict(reranker_input)

    # Step 4: Attach scores and rank videos
    scored_videos = pd.DataFrame(fetched_videos)
    scored_videos["score"] = scores
    ranked = scored_videos.sort_values(by="score", ascending=False)

    return ranked[["video_id", "title", "score"]]

# 🔍 Example usage:
ranked_for_cv_user = rerank_videos_for_user("user_cv", user_histories, fetched_videos)
print("Top videos for Computer Vision")
print(ranked_for_cv_user.head(5))
# Out:
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Top videos for Computer Vision
#    video_id                                              title     score
# 1         2              Best AI Tools for Programming in 2025  0.505542
# 59      100                           Computer Vision Class 10  0.464783
# 55       96  What is Computer Vision? | How does it work? |...  0.405216
# 41       82         20 Best Computer Vision Projects for 2025!  0.359751
# 54       95              How Computer Vision Applications Work  0.268234

# %% [markdown]
# # PairWise Reranking

# %%
from sentence_transformers import CrossEncoder
import pandas as pd
import numpy as np

def rerank_videos_for_user_pairwise(user_id, user_histories, fetched_videos, agg='mean'):
    model = CrossEncoder("BAAI/bge-reranker-base")

    # Prepare list to store all pairs and track which pair belongs to which fetched video
    pairs = []
    video_map = []  # to keep track of fetched_video index for each pair

    for fetched_idx, fetched_video in enumerate(fetched_videos):
        for user_video in user_histories[user_id]:
            user_text = f"{user_video['title']}. {user_video['description']}"
            fetched_text = f"{fetched_video['title']}. {fetched_video['description']}"
            pairs.append((user_text, fetched_text))
            video_map.append(fetched_idx)

    # Predict scores for all pairs at once
    scores = model.predict(pairs)

    # Aggregate scores per fetched video
    agg_scores = {}
    counts = {}

    for idx, score in enumerate(scores):
        vid_idx = video_map[idx]
        agg_scores.setdefault(vid_idx, 0)
        counts.setdefault(vid_idx, 0)
        agg_scores[vid_idx] += score
        counts[vid_idx] += 1

    # Calculate mean or max
    if agg == 'mean':
        final_scores = {vid_idx: agg_scores[vid_idx]/counts[vid_idx] for vid_idx in agg_scores}
    elif agg == 'max':
        # For max, we need to track max instead of sum; redo aggregation:
        max_scores = {}
        for idx, score in enumerate(scores):
            vid_idx = video_map[idx]
            if vid_idx not in max_scores or score > max_scores[vid_idx]:
                max_scores[vid_idx] = score
        final_scores = max_scores
    else:
        raise ValueError("Aggregation method must be 'mean' or 'max'")

    # Build DataFrame for results
    results = []
    for vid_idx, score in final_scores.items():
        results.append({
            "video_id": fetched_videos[vid_idx]["video_id"],
            "title": fetched_videos[vid_idx]["title"],
            "score": score
        })

    ranked = pd.DataFrame(results).sort_values(by="score", ascending=False)
    return ranked

# Example usage:
ranked_for_cv_user = rerank_videos_for_user_pairwise("user_cv", user_histories, fetched_videos, agg='mean')
print("Top videos for Computer Vision (pairwise):")
print(ranked_for_cv_user.head(5))
# Out:
# Batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Top videos for Computer Vision (pairwise):
#    video_id                                              title     score
# 46       87                     Computer Vision in 100 Seconds  0.155237
# 55       96  What is Computer Vision? | How does it work? |...  0.075408
# 50       91                          Computer Vision Explained  0.039538
# 54       95              How Computer Vision Applications Work  0.033930
# 59      100                           Computer Vision Class 10  0.002573

# %% [markdown]
# # Embedding Based

# %% [markdown]
# This approach uses vector embeddings of video titles and descriptions to represent their semantic content. While embeddings are commonly used to measure similarity between texts, here we specifically compute similarity scores between each video in the user’s watch history and each candidate video individually. These pairwise similarity scores are then aggregated—using methods like mean or max—to derive an overall relevance score for each candidate video.

# %% [markdown]
# Even though the approach increases accuracy, it can be computationally intensive.
# Suggestions: Limit user history to recent k videos (e.g., k = 10)
#              Apply fast filtering first (e.g., using simple keyword match or ANN  search), and only rerank top N candidates with this method. (Can achieve this using Youtube data API)

# %%
from sentence_transformers import SentenceTransformer, util
import pandas as pd
import numpy as np

def embed_texts(videos, model, batch_size=32):
    texts = [f"{v['title']}. {v['description']}" for v in videos]
    embeddings = model.encode(texts, batch_size=batch_size, convert_to_tensor=True, show_progress_bar=False)
    return embeddings

def rerank_videos_with_embeddings(user_id, user_histories, fetched_videos, agg="mean"):
    model = SentenceTransformer("BAAI/bge-base-en")  

    user_videos = user_histories[user_id]
    
    # Step 1: Embed user history and fetched videos
    user_embeds = embed_texts(user_videos, model)
    fetched_embeds = embed_texts(fetched_videos, model)

    # Step 2: Compute cosine similarity matrix (user_history_size x fetched_size)
    similarity_matrix = util.cos_sim(user_embeds, fetched_embeds).cpu().numpy()

    # Step 3: Aggregate similarity scores for each fetched video
    if agg == "mean":
        agg_scores = similarity_matrix.mean(axis=0)
    elif agg == "max":
        agg_scores = similarity_matrix.max(axis=0)
    else:
        raise ValueError("agg must be 'mean' or 'max'")

    # Step 4: Rank videos by aggregated score
    results = []
    for i, score in enumerate(agg_scores):
        results.append({
            "video_id": fetched_videos[i]["video_id"],
            "title": fetched_videos[i]["title"],
            "score": score
        })

    ranked = pd.DataFrame(results).sort_values(by="score", ascending=False)
    return ranked

# Example usage:
ranked_for_nlp_user = rerank_videos_with_embeddings("user_nlp", user_histories, fetched_videos, agg="mean")
print("Top videos for NLP:")
print(ranked_for_nlp_user.head(5))
# Out:
# Top videos for NLP:
#    video_id                                              title     score
# 52       93       Why Computer Vision Is a Hard Problem for AI  0.817694
# 57       98  Basic Computer Vision with ML (ML Zero to Hero...  0.810444
# 5         6  We Tested Google's New AI Coding Tool Opal (Ho...  0.802067
# 37       38                               What is Agentic RAG?  0.801020
# 28       29                               Agentic AI Explained  0.799880

# %% [markdown]
# Using Reranker on top of filtered videos using embeddings

# %%
from sentence_transformers import SentenceTransformer, CrossEncoder, util
import pandas as pd
import numpy as np

def embed_texts(videos, model, batch_size=32):
    texts = [f"{v['title']}. {v['description']}" for v in videos]
    embeddings = model.encode(texts, batch_size=batch_size, convert_to_tensor=True, show_progress_bar=False)
    return embeddings

def rerank_videos_with_embeddings_and_crossencoder(user_id, user_histories, fetched_videos, agg="mean"):
    embed_model = SentenceTransformer("BAAI/bge-base-en")
    rerank_model = CrossEncoder("BAAI/bge-reranker-base")

    user_videos = user_histories[user_id]

    # Step 1: Embed user history and fetched videos
    user_embeds = embed_texts(user_videos, embed_model)
    fetched_embeds = embed_texts(fetched_videos, embed_model)

    # Step 2: Compute cosine similarity matrix
    similarity_matrix = util.cos_sim(user_embeds, fetched_embeds).cpu().numpy()

    # Step 3: Aggregate similarity scores
    if agg == "mean":
        agg_scores = similarity_matrix.mean(axis=0)
    elif agg == "max":
        agg_scores = similarity_matrix.max(axis=0)
    else:
        raise ValueError("agg must be 'mean' or 'max'")

    # Step 4: Build video list with aggregated scores
    candidates = []
    for i, score in enumerate(agg_scores):
        candidates.append({
            "video_id": fetched_videos[i]["video_id"],
            "title": fetched_videos[i]["title"],
            "description": fetched_videos[i]["description"],
            "agg_score": score
        })

    # Step 5: Build query from user history (concatenated titles+descriptions)
    user_query = " ".join([f"{v['title']}. {v['description']}" for v in user_videos])

    # Step 6: Prepare input pairs for reranker
    rerank_inputs = [(user_query, f"{v['title']}. {v['description']}") for v in candidates]
    rerank_scores = rerank_model.predict(rerank_inputs)

    # Step 7: Assign rerank scores and sort
    for i, score in enumerate(rerank_scores):
        candidates[i]["final_score"] = score

    ranked = pd.DataFrame(candidates).sort_values(by="final_score", ascending=False)
    return ranked

# Example usage:
ranked_for_nlp_user = rerank_videos_with_embeddings_and_crossencoder("user_nlp", user_histories, fetched_videos, agg="mean")
print("Top videos for NLP after reranking:")
print(ranked_for_nlp_user[["video_id", "title", "final_score"]].head(5))
# Out:
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Top videos for NLP after reranking:
#    video_id                                              title  final_score
# 41       82         20 Best Computer Vision Projects for 2025!     0.640263
# 46       87                     Computer Vision in 100 Seconds     0.363841
# 59      100                           Computer Vision Class 10     0.358507
# 57       98  Basic Computer Vision with ML (ML Zero to Hero...     0.333801
# 1         2              Best AI Tools for Programming in 2025     0.333341
